# %% [markdown]
# # Medical Imaging

# %% [markdown]
# The main purpose of medical imaging in *conventional surgery* is to make the diagnosis process earlier and more accurate. It provides *insight* into human body that is otherwise not visible to direct human vision. Four imaging modalities are commonly used for medical interventions:
#
# 1. <wiki:X-ray> and <wiki:fluoroscopy>,
# 1. [Computed Tomography](https://en.wikipedia.org/wiki/CT_scan), or {term}`CT`,
# 1. <wiki:Magnetic_resonance_imaging>, or {term}`MRI`, and
# 1. <wiki:Medical_ultrasound>, or {term}`US`.
#
# Medical imaging are used to visualize the target anatomy (e.g. a tumour) and formulate an intervention strategy (e.g. surgical resection or ablation, depending on the size and location) before the commencement of surgery. Due to the physics of each imaging modality, tissues are imaged with different characteristics based on their interaction with the physics of imaging. For example, <wiki:X-ray> have the ability to penetrate matter, but the amount of penetrating X-ray photons is material-dependent. When X-ray passes through matter, they
# - interact with atomic electrons,
# - interact with necleons,
# - interact with electric fields associated to atomic electrons and atomic nuclei.
#
# Thus, denser materials, such as bone, attenuates <wiki:X-ray> photons much more than less-denser materials, such as soft-tissues, resulting on a brighter pixel intensity in <wiki:X-ray> imaging. Thus, while it is true that we are using medical imaging, and this is not a course on the physicals of medical imaging, you should nonetheless learn a bit about them.

# %% [markdown]
# ## Use of Medical Imaging for Surgical Interventions
#
# In general, the use of medical imaging for surgical interventions can be broadly divided into the following categories ([](https://doi.org/10.1007/978-3-540-71915-1_39))
# - *Pre-operative planning*: to establish the operating target and its surrounding anatomical structures for planning out detailed access and operating trajectories; it also involves the establishment of framerelated coordinate systems  based on anatomical or fiducial markers for linking the patient and imaging coordinate systems;
# - *Intra-operative guidance*: to provide real-time surgical guidance by providing anatomical and functional information about the operating site; increasingly, imaging is used in surgery for providing in situ tissue structure and function characterisation such that the direct outcome of the surgical procedure can be assessed. Augmented Reality ({term}`AR`) is one important form of intra-operative guidance whereby the imaging data are combined with the exposed anatomical surface to provide  *see-through* vision of the operating site;
# - *Post-operative assessment*: to assess the efficacy of the surgical procedure and the long-term benefit of therapeutic processes; for patients implanted with vessel prostheses or those who have undergone cancer surgery, serial image assessment provides an important monitoring tool for outcome management.
#
# In other words, the *pre*-, *intra*-, and *post*-operative usage of medical imaging parallels with the surgical {term}`CAD`, surgical {term}`CAM`, and {term}`TQM` as discussed before.

# %% [markdown]
# ```{figure} ./../images/004/imaging_roles.png
# :label: fig_imaging_roles
# :alt: Roles of Medical Imaging
# :align: center
# :width: 80%
#
# A shematic diagram showing how medical imaging is used for pre-operative planning, intra-operative guidance and post-operative assessment in surgery, as well as the key processes linking these components. Image courtesy of [](https://doi.org/10.1007/978-3-540-71915-1_39).
# ```

# %% [markdown]
# For the purpose of this course, thus, while you don't need to understand the *physics* of medical imaging, you nonetheless need a basic understanding of what {term}`MRI`, {term}`CT`, {term}`US` or <wiki:Position_emission_tomography> ({term}`PET`) are showing, from an imaging processing point of view. Thereby you'll develop an intution as to what algorithms are suitable for a particular types of medical imaging and their intended clinical applications.

# %% [markdown]
# ## Resolution
#
# Perhaps one of the most **mis**-used terminology in medical imaging is the word **resolutio**. For example, we often talked that "A TV has a *4K* **resolution**", where $4K$ is defined as a TV has $3840 \times 2160$ pixels in the width and height, respectively. However, it is perhaps better termed as "pixel count", as in how many pixel is used to represent an imaging, instead of an *image resolution*.
#
# **Resolution** is defined as
#
# > Closest distance two points can be and still be perceived as distinct points
#
# In this regard, *resolution* is measured as a distance (often in milli-metre), and not in pixels!
#
# ```{figure} ./../images/004/resolution.png
# :label: fig_resolution
# :alt: image resolution
# :align: center
# :width: 80%
#
# When a fiducial is images, it results in a <wiki:point_spread_function> (<span style="color:red">red curve</span>) that blurs the image. The word **resolution** refers to the fact if two <wiki:point_spread_function> can be **resolved** (told apart).
# ```

# %% [markdown]
# In medical imaging, resolution is often expressed as:
# - Distance, e.g. Resolution of 0.5mm, or
# - line-pairs/mm: minimum of lines that can be resolved per milli-metre.
#
# In this regard, *resolution* is measured as a distance (often in milli-metre), and not in pixels!
#
# ```{figure} ./../images/004/imaging_resolution.png
# :label: fig_imaging_resolution
# :alt: Measuring resolution
# :align: center
# :width: 80%
#
# How image resolution can be measured. Image courtesy of {cite}`BSL+2020`
# ```

# %% [markdown]
# ## Medical Ultrasound
#
# {term}`US` has become the preferred *non-invasive* imaging modality due to their non-ionizing radiation nature and their ability to image soft tissues. The working principal of {term}`US` are
# - time of flight, and
# - sound wave reflects and refracts when travelling from one medium to another (with different densities)
#
# In this regard, {term}`US` is able to image organ boundaries and internal organ structures, including changes caused by, as an example, tumour growths. The main advantages of {term}`US` are the **real-time** nature, capable of *live* imaging (i.e. video), portability, and (relative) cost.
#
# ```{figure} https://www.nibib.nih.gov/sites/default/files/inline-images/Fetal%20ultrasound_Phillips%20Healthcare.png
# :label: fig_Medical_Ultrasound
# :alt: Medical Ultrasound
# :align: center
# :width: 80%
#
# Cross-section {term}`US` image of a fetus, image courtesy [here](https://www.nibib.nih.gov/science-education/science-topics/ultrasound), accessed on 2026-02-03.
# ```

# %% [markdown]
# For {term}`US` imaging, the resolution **scales as the inverse of the acoustic frequency**, which for modern equipment is generally less than 1mm ($\approx 2.5$MHz). However, as the acoustic frequency increases, the **penetration depth** decreases due to the increased absorption, leading to a trade-off between image resolution and penetration depth.
#
# The main application of {term}`US` is both *functional* and *structural*, used to image anatomy with motion (i.e. cardiac with beating heart) or flow (i.e. via <wiki:Doppler_ultrasonography> for cardiovascular). {term}`US` is widely used in cardiovascular, hepatobiliary, pancreatic, renal or gynaecological problems, or in obstetrics to visualise the foetus ([](https://doi.org/10.1007/978-3-540-71915-1_39)).
#
# ```{figure} ./../images/004/doppler_ultrasound.png
# :label: fig_doppler_ultrasound
# :alt: Doppler Ultrasound
# :align: center
# :width: 80%
#
# A Doppler ultrasound to visualize the direction and velocity of the blood flow.
# ```

# %% [markdown]
# ### 3D Ultrasound
# While most of the clinical ultrasound are {term}`2D` image modality, modern {term}`US` in fact has {term}`3D` capability. There are several mechanisms to achieve {term}`3D` {term}`US`, with *real-time* {term}`3D` {term}`US` achievd by ultrasound transducer equipped with a **matrix-array** of [piezoelectric](https://en.wikipedia.org/wiki/Piezoelectric_sensor) elements.
#
# ```{figure} ./../images/004/3D_US.png
# :label: fig_3D_US
# :alt: Doppler Ultrasound
# :align: center
# :width: 80%
#
# A {term}`3D` {term}`US` volume depicting the <wiki:Tricuspid_valve> at the [right ventricle](https://en.wikipedia.org/wiki/Ventricle_(heart)#Structure) of the <wiki:heart>.
# ```
#
# Compared to {term}`2D` {term}`US`, {term}`3D` {term}`US` in general has lower resolution and slower frame rate.

# %% [markdown]
# ## X-ray
#
# <wiki:X-rays> are high-energy electromagnetic waves that only interact very weakly with tissue, although different tissues will absorb the radiation to varying degrees. Images of the radiation that has passed through the body can be recorded after the <wiki:X-rays> have directly or indirectly interacted with a phosphor screen that emits light. This light can be recorded on photographic film or a digital camera or can be amplifi ed by an image intensifier. <wiki:X-rays> imaging is the most common form of pre-operative planning, and in conventional radiology, the contrast in the images is generated by differences between soft tissue (mainly water), bone, fat and air or gas. This method is typically used for musculoskeletal imaging as bone absorbs <wiki:X-rays> more strongly than soft tissue, and the images can be used to detect [fractures](https://en.wikipedia.org/wiki/Bone_fracture), <wiki:tuberculosis> of the spine, benign and malignant tumours, <wiki:osteoarthritis>, <wiki:rheumatoid_arthritis> and <wiki:gout>. To improve the contrast available in <wiki:X-rays> imaging, [iodine](https://en.wikipedia.org/wiki/Iodinated_contrast) (for intravenous and intra-arterial <wiki:angiography>) or <wiki:barium_sulphate> (for investigation of the GI tract) may be administered, as these atoms highly absorb <wiki:X-rays>.
#
# ```{figure} https://upload.wikimedia.org/wikipedia/commons/7/79/First_medical_X-ray_by_Wilhelm_R%C3%B6ntgen_of_his_wife_Anna_Bertha_Ludwig%27s_hand_-_18951222.jpg
# :label: fig_first_xray
# :alt: First Medical X-ray image
# :align: center
# :width: 80%
#
# Considered as the **first** medical imaging, this is Hand mit Ringen (Hand with Rings): print of Wilhelm Röntgen's first "medical" X-ray, of his wife's hand, taken on 22 December 1895 and presented to Ludwig Zehnder of the Physik Institut, University of Freiburg, on 1 January 1896. Image courtesy of Wilhelm Röntgen, Public domain, via Wikimedia Commons, accessed [here](https://commons.wikimedia.org/wiki/File:First_medical_X-ray_by_Wilhelm_R%C3%B6ntgen_of_his_wife_Anna_Bertha_Ludwig%27s_hand_-_18951222.jpg) on 2026-02-03.
# ```

# %% [markdown]
# <wiki:X-rays> was discovered by [Wilhelm Röntgen](https://en.wikipedia.org/wiki/Wilhelm_R%C3%B6ntgen), a German Physics professor in 1895. Within weeks, on February 14, 1896, <wiki:John_Hall-Edwards> used x-ray in a surgical operation. At the time though, the harmful impact of ionizing radiation to biological tissues was unknown, and Hall-Edwards' interest in X-ray cost him his left arm due to advanced cancer.
#
# ```{figure} https://upload.wikimedia.org/wikipedia/commons/8/89/Amputated_hand_of_John_Hall-Edwards.png
# :label: fig_Hall-Edwards
# :alt: Hall-Edwards
# :align: center
# :width: 80%
#
# The amputated left hand of John Hall-Edwards, following extensive radiation damage. Image courtesy of Archon 2488, [CC BY-SA 4.0](https://creativecommons.org/licenses/by-sa/4.0), via Wikimedia Commons, accessed [here](https://commons.wikimedia.org/wiki/File:Amputated_hand_of_John_Hall-Edwards.png) on 2026-02-03.
# ```

# %% [markdown]
# ### Interpretation of X-ray image
#
# The interpretation of the {term}`2D` projections produced in <wiki:X-rays> imaging can be difficult, especially in anatomically complicated structures and overlapping tissues, and it is common to use X-ray {term}`CT` in these situations. As <wiki:X-rays> imaging is a function of the <wiki:X-rays> attenuation, it is important to remember that:
# - Attenuation is related to atomic number or electron density of atoms in beam path,
# - Most body tissues are carbon-, hydrogen-, oxygen-, and nitrogen- based, atomic masses of 12, 1, 16, and 14 respectively. There are traces of Calcium (40) and iron (56) as well.
#
# In this regard, a **transparent** tissue between the X-ray source and image detector implies that more photons strike detector giving a bright image. Intermediate transparent causes gray image.
#
# ```{figure} ./../images/004/X-ray_imaging.png
# :label: fig_xray_intensity
# :alt: X-ray Intensity
# :align: center
# :width: 80%
#
# <wiki:X-rays> image is formed with an <wiki:X-rays> source and an image detector (beneath the patient). Image intensity at a point z depends on the x-ray attenuation of the <wiki:X-rays> beam within the tissue. Image courtesy of {cite}`BSL+2020`
# ```

# %% [markdown]
# ### X-ray systems
#
# Catagorically, there are 2 types of X-ray imaging system:
# - Radiography that takes a single, stationary, <wiki:X-rays> image, and
# - <wiki:Fluoroscopy>, that uses low-dose <wiki:X-rays> and acquiring contineous (i.e. video) images. Fluoroscopy can be either stationary or is on a rotational platform.
#
# ```{figure} ./../images/004/X-ray_system.png
# :label: fig_xray_system
# :alt: X-ray Systems
# :align: center
# :width: 80%
# (perhaps old) X-ray imaging system. The Radiography (R/F) System take a stationary, single, x-ray image, where as the C-arm system has the x-ray source and detectors on a rotating platform that has the capability to take contineous images (i.e. video). Image courtesy of {cite}`BSL+2020`
# ```

# %% [markdown]
# ### Angiography
#
# <wiki:Angiography> is a medical imaging techniques used to visualize the inside of blood vessels and organs of the body, performed by injecting a radio-opaque contrast agent into the blood vessels and imaging using <wiki:X-ray> based techniques such as <wiki:fluoroscopy>.
#
# ```{figure} https://upload.wikimedia.org/wikipedia/commons/3/30/Cerebral_angiography%2C_arteria_vertebralis_sinister_injection.JPG
# :label: fig_Angio
# :alt: Angiography
# :align: center
# :width: 80%
#
# <wiki:Cerebral_angiography>, injection in the left <wiki:vertebral_artery>, with retrograde flow in the contralateral vertebral artery, the <wiki:basilar_artery> and the <wiki:posterior_communicating_artery>. The posterior cerebral circulation can be seen, including the posterior part of the <wiki:Circle_of_Willis>. Image courtesy of Lipothymia, Public domain, via Wikimedia Commons, accessed [here](https://commons.wikimedia.org/wiki/File:Cerebral_angiography,_arteria_vertebralis_sinister_injection.JPG) on 2026-02-04.
# ```

# %% [markdown]
# ## Computed Tomography
#
# In {term}`CT`, the absorption of the tissue is recorded as the X-ray source and a one-dimensional array of detectors are rotated around the patient’s body, resulting in a number of one-dimensional projections recorded at different orientations of the body (called sinograms).
#
# In {term}`CT`, the X-rays are collimated so that only a thin slice of the patient is probed during each acquisition. Image reconstruction can then be performed to create a cross-sectional image, where each pixel of the image represents the absorption of a given region of the crosssection. This whole procedure can then be repeated at different slice positions to build up a 3D volumetric model of the patient. Common applications of {term}`CT` include investigations in staging of various tumours, calcifi cation, lung cancer, cerebral infarction, haemorrhage and abscesses, complex fractures, pulmonary diseases such as emboli and detection of acute and chronic pancreatitis.
#
# The pixel intensity of a {term}`CT` is measured in <wiki:Hounsfield_scale> ({term}`HU`), defined as:
#
# ```{math}
# HU = 1000 \times \frac{\mu-\mu_{water}}{\mu_{water} - \mu_{air}}
# ```
# where $\mu_{water}$ and $\mu_{air}$ are respectively the linear attenuation coefficients of water and air. In this regard, {term}`CT` is calibrated with reference to water and other materials to ensure *standardised response*.

# %% [markdown]
# ### Scanning Geometry
#
# Conceptually, a {term}`2D` CT image is acquired by rotating an X-ray source and detectors about the scanned object, and {term}`3D` CT volume is reconstructed from {term}`2D` CT image by translating the X-ray source and the detectors axially along the object. Modern CT geometry has the capability to acquire multiple slices per revolution, leading to shortened acqusition time and resuced slice thickness (improved axial resolution).
#
# ```{figure} ./../images/004/CT_Geometry.png
# :label: fig_CT_Geometry
# :alt: CT numbers
# :align: center
# :width: 80%
#
# Scanning geometry of {term}`CT`, Image courtesy of Prof. Terry M. Peters at Robarts Research Institute, Canada.
# ```

# %% [markdown]
# ### Resolution and Contrast
#
# ```{figure} ./../images/004/CT_HU.png
# :label: fig_CT_HU
# :alt: CT numbers
# :align: center
# :width: 80%
#
# CT numbers ({term}`HU`) of various tissues. Image courtesy of {cite}`BSL+2020`
# ```
#
# [](#fig_CT_HU) lists the {term}`HU` for verious tissue types. Notices that most of the soft-tissues, such as kidney and liver, have very similiar {term}`HU` values. You should ask yourself why!  That is to say, {term}`CT` has very low **image contrast** for soft-tissues and thus one may not be able to differentiate soft-tissues of different types from {term}`CT` easily.
#
# The *in-plane* resolution of a {term}`CT` image can be quite high, limited by the number of detectors. The *out-of-plane* resolution, i.e. the axial resolution, could be lower than that of the *in-plane* resolution, limited by the amount of translation of the translation used to move the object relative to the X-ray source and detectors. Modern {term}`CT` scanners use in clinical setting are capable to achieve a resolution of $0.3mm \times 0.3mm \times 0.3mm$ or better.

# %% [markdown]
# ```{figure} ./../images/004/CT_Toshiba.png
# :label: fig_CT_Toshiba
# :alt: CT numbers
# :align: center
# :width: 80%
#
# Toshiba Aquilion {term}`CT` scanner, capable of scanning of 320 slices per rotation at 0.35 second per rotation.
# ```
#
# ```{figure} ./../images/004/CT_liver.png
# :label: fig_CT_liver
# :alt: CT numbers
# :align: center
# :width: 80%
#
# {term}`CT` scan of a liver, Image courtesy of Prof. Terry M. Peters at Robarts Research Institute, Canada.
# ```

# %% [markdown]
# ## Magnetic Resonance Imaging
#
# Magnetic Resonance Imaging ({term}`MRI`) allows the density of nuclei in the tissue, particularly hydrogen found in water, to be imaged. The main advantages of {term}`MRI` lie in the excellent soft tissue contrast it provides, the absence of absorption and shadow artefacts caused by the presence of bones and also the absence of ionising radiation required for {term}`CT`/radionuclide methods. The intrinsic contrast of the MR signal can be programmed to reflect proton density and different relaxation effects of the tissue. It is emerging as an important tool for pre-operative planning because of its safety, versatility and the high-quality images it produces that allow accurate and reproducible quantification of structure and function such as blood flow and perfusion

# %% [markdown]
# ```{figure} ./../images/004/MRI_T1_T2.png
# :label: fig_MRI_head
# :alt: CT numbers
# :align: center
# :width: 80%
#
# {term}`MRI` scans of a head, demonstrating the same anatomy but imaged using different [pulse sequence](https://en.wikipedia.org/wiki/MRI_pulse_sequence). Image courtesy of Prof. Terry M. Peters at Robarts Research Institute, Canada.
# ```

# %% [markdown]
# ### MRI System
# While a {term}`MRI` machine looks similar to a {term}`CT` machine, having a round opening in the middle, internally they are quite different.
#
# ```{figure} https://upload.wikimedia.org/wikipedia/commons/7/79/GE_Signa_MRI.JPG
# :label: fig_MRI_machine
# :alt: MRI Machine
# :align: center
# :width: 80%
#
# <wiki:Cerebral_angiography>, injection in the left <wiki:vertebral_artery>, with retrograde flow in the contralateral vertebral artery, the <wiki:basilar_artery> and the <wiki:posterior_communicating_artery>. The posterior cerebral circulation can be seen, including the posterior part of the <wiki:Circle_of_Willis>. Image courtesy of BrokenSphere, [CC BY-SA 3.0](https://creativecommons.org/licenses/by-sa/3.0), via Wikimedia Commons, accessed [here](https://commons.wikimedia.org/wiki/File:GE_Signa_MRI.JPG) on 2026-02-04.
# ```

# %% [markdown]
# Inside of an MRI machine has 3 different types of electromagnets:
# 1. The main component is a large hallow cylindrical superconducting magnet,
# 1. [*Gradient*](https://en.wikipedia.org/wiki/Physics_of_magnetic_resonance_imaging#Gradients) coils (electromagnets) to shape field, and
# 1. *Radio-frequency* coils (antennas) to transmit high-frequency electromagnetic fields to excite nuclei.
#
# ```{figure} ./../images/004/MRI_coils.png
# :label: fig_MRI_coils
# :alt: CT numbers
# :align: center
# :width: 80%
#
# The internal of an {term}`MRI` machine has 3 kinds of electromagnetic coils: the main magnet, the gradient coils, and radio frequency coil. Image courtesy of Prof. Terry M. Peters at Robarts Research Institute, Canada.
# ```

# %% [markdown]
# ### MRI scanning and Metal
#
# {term}`MRI`, however, is not compatible with ferromegnetic materials, thus it is unsuitable for patients with metallic implants. Care must be taken not to bring ferromagnetic objects near the scanner during the operation as they can be foicibly attracted by the strong magnetic fields.
#
# <iframe width="80%" src="https://www.youtube.com/embed/6BBx8BwLhqg?si=izwdOL4MHO3L4vOV" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>

# %% [markdown]
# ### Applications
#
# Applications of MRI include cardiovascular, brain, spine and joint imaging, where it may be used to discriminate between subtle variations in soft tissue with excellent spatial resolution. Other applications include the detection of intracranial tumours, knee cartilage tears, lumbar disc disease and the staging of malignant tumours. It is also possible to add contrast agents including intravenous gadolinium to reveal tissue perfusion, soft tissue tumours and perform <wiki:Magnetic_resonance_angiography>.
#
# ```{figure} https://upload.wikimedia.org/wikipedia/commons/6/66/Mra-mip.jpg
# :label: fig_MRI_angio
# :alt: MRI Angiography
# :align: center
# :width: 80%
# Time-of-flight <wiki:Magnetic_resonance_angiography> at the level of the <wiki:Circle_of_Willis>. Image courtesy of SBarnes, [CC BY-SA 3.0](https://creativecommons.org/licenses/by-sa/3.0), via Wikimedia Commons, accessed [here](https://commons.wikimedia.org/wiki/File:Mra-mip.jpg) on 2026-02-04.
# ```

# %% [markdown]
# ### Functional {term}`MRI`
#
# [Functional MRI](https://en.wikipedia.org/wiki/Functional_magnetic_resonance_imaging) measures brain activity by detecting changes associated with floor flow.
#
# ```{figure} https://upload.wikimedia.org/wikipedia/commons/4/4a/1206_FMRI.jpg
# :label: fig_fMRI
# :alt: function MRI
# :align: center
# :width: 80%
# An [fMRI](https://en.wikipedia.org/wiki/Functional_magnetic_resonance_imaging) image with yellow areas showing increased activity compared with a control condition. Image courtesy of OpenStax, [CC BY 4.0](https://creativecommons.org/licenses/by/4.0>), via Wikimedia Commons, accessed [here](https://commons.wikimedia.org/wiki/File:1206_FMRI.jpg) on 2026-02-04.
# ```
